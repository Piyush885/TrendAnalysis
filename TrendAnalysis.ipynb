# %%
import pandas as pd
import numpy as np
import matplotlib
import nltk
from nltk.corpus import stopwords
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.feature_extraction.text import CountVectorizer

# %%
nltk.download("stopwords")
stopwords = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# %%
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
df = pd.read_csv("My Library sorted 2000 use.csv")

# %%
df
# Out:
#            Key        Item Type  Publication Year  \
# 0     9RFNUFEF   journalArticle              2023
# 1     WFXADHWQ      bookSection              2023
# 2     Y3QMD4BL   journalArticle              2023
# 3     MTHPMMNG      bookSection              2023
# 4     49XI7BNG      bookSection              2023
# ...        ...              ...               ...
# 6050  K94RQ3BW  conferencePaper              2000
# 6051  3AFEH9Q9  conferencePaper              2000
# 6052  UC7DEIRP  conferencePaper              2000
# 6053  238I887S  conferencePaper              2000
# 6054  4WX4W4XS  conferencePaper              2000
#
#                                                  Author  \
# 0     Savić Tot, Tijana; Adžić, Slobodan; Tot, Vilmo...
# 1     Ahmad, Ala’eddin M.; Abuhashesh, Mohammad; Nus...
# 2         St-Onge, Cédric; Kara, Nadjia; Edstrom, Claes
# 3     Wong, W. Eric; Gao, Ruizhi; Li, Yihao; Abreu, ...
# 4     Megdadi, Younes; Hammouri, Mohammad; Megdadi, ...
# ...                                                 ...
# 6050  El-Korany, Abeer; Rafea, Ahmed; Baraka, Hoda; ...
# 6051  Labiche, Y.; Thévenod-Fosse, P.; Waeselynck, H...
# 6052         Mařík, Vladimír; Král, Luboš; Mařík, Radek
# 6053                            Chen, T. Y.; Lau, M. F.
# 6054             Lee, M.; Offutt, A.J.; Alexander, R.T.
#
#                                                   Title  \
# 0     The impact of time devoted to video games on s...
# 1     Environmental Forces Influencing Perceived Acc...
# 2     Multivariate outlier filtering for A-NFVLearn:...
# 3     Software Fault Localization: an Overview of Re...
# 4     The Impact of Facebook Advertisements on Custo...
# ...                                                 ...
# 6050  A Structured Testing Methodology for Knowledge...
# 6051        Testing levels for object-oriented software
# 6052  Software Testing & Diagnostics: Theory & Practice
# 6053  On the Minimal Essential Subsets and Minimal R...
# 6054  Algorithmic analysis of the impacts of changes...
#
#                                       Publication Title               ISBN  \
# 0                Education and Information Technologies                NaN
# 1     The Effect of Information Technology on Busine...  978-3-031-12382-5
# 2                         The Journal of Supercomputing                NaN
# 3               Handbook of Software Fault Localization  978-1-119-88092-9
# 4     The Effect of Information Technology on Busine...  978-3-031-12382-5
# ...                                                 ...                ...
# 6050           Database and Expert Systems Applications  978-3-540-44469-5
# 6051  Proceedings of the 22nd international conferen...  978-1-58113-206-9
# 6052    SOFSEM 2000: Theory and Practice of Informatics  978-3-540-44411-4
# 6053     Reliable Software Technologies Ada-Europe 2000  978-3-540-45098-6
# 6054  Proceedings. 34th International Conference on ...                NaN
#
#            ISSN                         DOI  \
# 0     1573-7608  10.1007/s10639-022-11418-5
# 1           NaN                         NaN
# 2     1573-0484  10.1007/s11227-023-05283-3
# 3           NaN                         NaN
# 4           NaN                         NaN
# ...         ...                         ...
# 6050        NaN    10.1007/3-540-44469-6_40
# 6051        NaN       10.1145/337180.337197
# 6052        NaN     10.1007/3-540-44411-4_7
# 6053        NaN         10.1007/10722060_26
# 6054        NaN   10.1109/TOOLS.2000.868959
#
#                                                     Url  ...  \
# 0            https://doi.org/10.1007/s10639-022-11418-5  ...
# 1         https://doi.org/10.1007/978-3-031-12382-5_129  ...
# 2            https://doi.org/10.1007/s11227-023-05283-3  ...
# 3     https://onlinelibrary.wiley.com/doi/10.1002/97...  ...
# 4          https://doi.org/10.1007/978-3-031-12382-5_10  ...
# ...                                                 ...  ...
# 6050                                                NaN  ...
# 6051       https://dl.acm.org/doi/10.1145/337180.337197  ...
# 6052                                                NaN  ...
# 6053                                                NaN  ...
# 6054                                                NaN  ...
#
#      Programming Language Version System Code Code Number Section  Session  \
# 0                     NaN     NaN    NaN  NaN         NaN     NaN      NaN
# 1                     NaN     NaN    NaN  NaN         NaN     NaN      NaN
# 2                     NaN     NaN    NaN  NaN         NaN     NaN      NaN
# 3                     NaN     NaN    NaN  NaN         NaN     NaN      NaN
# 4                     NaN     NaN    NaN  NaN         NaN     NaN      NaN
# ...                   ...     ...    ...  ...         ...     ...      ...
# 6050                  NaN     NaN    NaN  NaN         NaN     NaN      NaN
# 6051                  NaN     NaN    NaN  NaN         NaN     NaN      NaN
# 6052                  NaN     NaN    NaN  NaN         NaN     NaN      NaN
# 6053                  NaN     NaN    NaN  NaN         NaN     NaN      NaN
# 6054                  NaN     NaN    NaN  NaN         NaN     NaN      NaN
#
#      Committee History  Legislative Body
# 0          NaN     NaN               NaN
# 1          NaN     NaN               NaN
# 2          NaN     NaN               NaN
# 3          NaN     NaN               NaN
# 4          NaN     NaN               NaN
# ...        ...     ...               ...
# 6050       NaN     NaN               NaN
# 6051       NaN     NaN               NaN
# 6052       NaN     NaN               NaN
# 6053       NaN     NaN               NaN
# 6054       NaN     NaN               NaN
#
# [6055 rows x 87 columns]

# %%
def tokenize_and_lemmatize(text):
    tokens = word_tokenize(text)  # Tokenize sentence into words
    lemmatizer = WordNetLemmatizer()
    lemmas = [lemmatizer.lemmatize(token.lower()) for token in tokens if token.lower() not in stopwords]  # Lemmatize tokens and remove stopwords
    return lemmas

# %%
df['lemmas'] = df['Publication Title'].apply(tokenize_and_lemmatize)

# %%
df['lemmas']
# Out:
# 0                    [education, information, technology]
# 1       [effect, information, technology, business, ma...
# 2                               [journal, supercomputing]
# 3               [handbook, software, fault, localization]
# 4       [effect, information, technology, business, ma...
#                               ...
# 6050              [database, expert, system, application]
# 6051    [proceeding, 22nd, international, conference, ...
# 6052     [sofsem, 2000, :, theory, practice, informatics]
# 6053    [reliable, software, technology, ada-europe, 2...
# 6054    [proceeding, ., 34th, international, conferenc...
# Name: lemmas, Length: 6055, dtype: object

# %%
df['lemmas_str'] = df['lemmas'].apply(lambda lemmas: ' '.join(lemmas))

# %%
# converting lemma to string---
df['lemmas_str']
# Out:
# 0                        education information technology
# 1       effect information technology business marketi...
# 2                                  journal supercomputing
# 3                    handbook software fault localization
# 4       effect information technology business marketi...
#                               ...
# 6050                   database expert system application
# 6051    proceeding 22nd international conference softw...
# 6052            sofsem 2000 : theory practice informatics
# 6053         reliable software technology ada-europe 2000
# 6054    proceeding . 34th international conference tec...
# Name: lemmas_str, Length: 6055, dtype: object

# %%
# Create document-term matrix
vectorizer = CountVectorizer()
dtm = vectorizer.fit_transform(df['lemmas_str'])
dtm
# Out:
# <6055x2171 sparse matrix of type '<class 'numpy.int64'>'
# 	with 34689 stored elements in Compressed Sparse Row format>

# %%
# Apply LDA
lda = LatentDirichletAllocation(n_components=3)  # Specify the desired number of topics
lda.fit(dtm)
# Out:
# LatentDirichletAllocation(n_components=3)

# %%
# Get the topic distributions for each document
topic_distributions = lda.transform(dtm)
df['topic_distribution'] = list(topic_distributions)
# Determine dominant topic for each document
dominant_topics = topic_distributions.argmax(axis=1)

# %%
# Add dominant topic to DataFrame
df['dominant_topic'] = dominant_topics

# Display the DataFrame with the original sentences, lemmas, and dominant topics
print(df[['Publication Title', 'lemmas', 'dominant_topic']])
# Out:
#                                       Publication Title  \
# 0                Education and Information Technologies
# 1     The Effect of Information Technology on Busine...
# 2                         The Journal of Supercomputing
# 3               Handbook of Software Fault Localization
# 4     The Effect of Information Technology on Busine...
# ...                                                 ...
# 6050           Database and Expert Systems Applications
# 6051  Proceedings of the 22nd international conferen...
# 6052    SOFSEM 2000: Theory and Practice of Informatics
# 6053     Reliable Software Technologies Ada-Europe 2000
# 6054  Proceedings. 34th International Conference on ...
#
#                                                  lemmas  dominant_topic
# 0                  [education, information, technology]               1
# 1     [effect, information, technology, business, ma...               2
# 2                             [journal, supercomputing]               0
# 3             [handbook, software, fault, localization]               1
# 4     [effect, information, technology, business, ma...               2
# ...                                                 ...             ...
# 6050            [database, expert, system, application]               1
# 6051  [proceeding, 22nd, international, conference, ...               0
# 6052   [sofsem, 2000, :, theory, practice, informatics]               1
# 6053  [reliable, software, technology, ada-europe, 2...               2
# 6054  [proceeding, ., 34th, international, conferenc...               0
#
# [6055 rows x 3 columns]

# %%
print(df[['Publication Title', 'lemmas', 'topic_distribution']])
# Out:
#                                       Publication Title  \
# 0                Education and Information Technologies
# 1     The Effect of Information Technology on Busine...
# 2                         The Journal of Supercomputing
# 3               Handbook of Software Fault Localization
# 4     The Effect of Information Technology on Busine...
# ...                                                 ...
# 6050           Database and Expert Systems Applications
# 6051  Proceedings of the 22nd international conferen...
# 6052    SOFSEM 2000: Theory and Practice of Informatics
# 6053     Reliable Software Technologies Ada-Europe 2000
# 6054  Proceedings. 34th International Conference on ...
#
#                                                  lemmas  \
# 0                  [education, information, technology]
# 1     [effect, information, technology, business, ma...
# 2                             [journal, supercomputing]
# 3             [handbook, software, fault, localization]
# 4     [effect, information, technology, business, ma...
# ...                                                 ...
# 6050            [database, expert, system, application]
# 6051  [proceeding, 22nd, international, conference, ...
# 6052   [sofsem, 2000, :, theory, practice, informatics]
# 6053  [reliable, software, technology, ada-europe, 2...
# 6054  [proceeding, ., 34th, international, conferenc...
#
#                                      topic_distribution
# 0     [0.08333743436262646, 0.8333243636567178, 0.08...
# 1     [0.04181453336563802, 0.4394791835788295, 0.51...
# 2     [0.7592506969768746, 0.12536453374096268, 0.11...
# 3     [0.07618225702810098, 0.8110242081303477, 0.11...
# 4     [0.04181453336563802, 0.4394791835788295, 0.51...
# ...                                                 ...
# 6050  [0.06684107049362879, 0.8659811648384457, 0.06...
# 6051  [0.8802233073955225, 0.05111831269394795, 0.06...
# 6052  [0.0558503732142118, 0.8833293136685941, 0.060...
# 6053  [0.048993260064845105, 0.3439051376871725, 0.6...
# 6054  [0.5358928988220218, 0.33799563590133913, 0.12...
#
# [6055 rows x 3 columns]
